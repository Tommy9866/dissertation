# %%
import pandas as pd
import glob
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text

# Step 1: Read all CSV files matching the pattern *_result.csv
file_pattern = "*_result.csv"
files = glob.glob(file_pattern)

# Initialize a list to hold dataframes
dfs = []

# Read each file, rank the methods within each file, and append to the list
for file in files:
    df = pd.read_csv(file, index_col=0)  # Set the first column as the index
    df['CV Mean Accuracy Rank'] = df['CV Mean Accuracy'].rank(ascending=False)
    dfs.append(df)

# Concatenate all dataframes
all_results = pd.concat(dfs, ignore_index=False)

# Step 2: Compute mean rank for each method across all datasets
mean_rank = all_results.groupby(all_results.index)['CV Mean Accuracy Rank'].mean()

# Step 3: Compute mean of Computation Time (Total)
mean_computation_time = all_results.groupby(all_results.index)['Computation Time (Total)'].mean()

# Prepare data for plotting
plot_data = pd.DataFrame({
    'Mean Rank of CV Mean Accuracy': mean_rank,
    'Mean Computation Time (Total)': mean_computation_time
})

# Step 4: Plot the graph with improved visualization
plt.figure(figsize=(12, 8))

# Create a color palette
color_palette = sns.color_palette("husl", n_colors=len(plot_data))

# Create the scatter plot with different colors and markers for each model
markers = ['o', 's', '^', 'D', 'v', '<', '>', 'p', '*', 'h', 'H', 'd']  # Different marker shapes
for i, (model, row) in enumerate(plot_data.iterrows()):
    plt.scatter(row['Mean Rank of CV Mean Accuracy'], row['Mean Computation Time (Total)'], 
                s=100, alpha=0.7, color=color_palette[i], label=model, 
                marker=markers[i % len(markers)], edgecolors='black', linewidth=1)

plt.yscale('log')  # Use log scale for y-axis only

plt.xlabel('Mean Rank of CV Mean Accuracy')
plt.ylabel('Mean of Computation Time (Total) (log scale)')
plt.title('Classification Model Comparison: Performance vs Computation Time')
plt.grid(True, which="both", ls="-", alpha=0.2)

# Adjust x-axis
plt.xlim(0, 23)  # Adjust x-axis range to fit the number of methods
plt.xticks(np.arange(0, 24, 1))  # Set x-ticks to range from 0 to 25 with 1 unit per grid

# Annotate points with model names
texts = []
for model, row in plot_data.iterrows():
    texts.append(plt.text(row['Mean Rank of CV Mean Accuracy'], row['Mean Computation Time (Total)'],
                          model, fontsize=8, fontweight='bold'))

# Adjust text to prevent overlap
adjust_text(texts, arrowprops=dict(arrowstyle='-', color='grey', lw=0.5))

# Add a point in the lower-left corner to illustrate preference
preferred_x = 1  # Example x-coordinate
preferred_y = min(plot_data['Mean Computation Time (Total)']) * 0.5  # Example y-coordinate for log scale
plt.scatter(preferred_x, preferred_y, color='yellow', s=150, edgecolors='black', label='Ideal model')

# Annotate the preferred point
plt.annotate('Ideal model', (preferred_x, preferred_y), 
             xytext=(10, 10), textcoords='offset points', 
             fontsize=10, color='black', fontweight='bold')

# Add legend
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

# Adjust layout to prevent cutting off labels
plt.tight_layout()

plt.show()

# Print the data for verification
print(plot_data.sort_values('Mean Rank of CV Mean Accuracy'))
# Out:
#                             Mean Rank of CV Mean Accuracy  \
# CatBoost                                         5.666667
# XGBoost                                          6.555556
# LightGBM + NN                                    6.833333
# LightGBM                                         7.277778
# Random Forest                                    8.444444
# Gradient Boosting                                8.666667
# Wide_and_Deep                                    9.555556
# KAN                                              9.555556
# MLP                                              9.777778
# Neural Architecture Search                      10.055556
# NODE                                            10.750000
# FT-Transformer                                  11.500000
# DCN                                             11.777778
# AutoInt + NN                                    12.222222
# SAINT                                           12.375000
# XGBoost + NN                                    12.777778
# DNN                                             13.111111
# KNN                                             14.000000
# Logistic Regression                             15.722222
# TabNet                                          15.812500
# Decision Tree                                   16.222222
#
#                             Mean Computation Time (Total)
# CatBoost                                        80.360923
# XGBoost                                          9.076734
# LightGBM + NN                                  107.163677
# LightGBM                                        28.321964
# Random Forest                                   42.285823
# Gradient Boosting                               41.569419
# Wide_and_Deep                                   77.009403
# KAN                                             37.736868
# MLP                                            265.617904
# Neural Architecture Search                      95.862046
# NODE                                           200.816374
# FT-Transformer                                 169.929809
# DCN                                            121.156672
# AutoInt + NN                                   137.348619
# SAINT                                          584.819322
# XGBoost + NN                                    84.089618
# DNN                                             81.292831
# KNN                                              0.365910
# Logistic Regression                              4.084685
# TabNet                                         590.288251
# Decision Tree                                    0.559199
